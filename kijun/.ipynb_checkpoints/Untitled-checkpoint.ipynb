# %%
import pandas as pd

df = pd.read_csv('../data/train.csv', encoding = 'utf-8')
df.isnull().sum()
df['핵심적발'].value_counts()
# Out:
# 0    68795
# 2    10581
# 1     9979
# Name: 핵심적발, dtype: int64

# %%
df['우범여부'].value_counts()
# Out:
# 0    68795
# 1    20560
# Name: 우범여부, dtype: int64

# %%
df.isnull().sum()
# Out:
# 신고번호            0
# 신고일자            0
# 통관지세관부호         0
# 신고인부호           0
# 수입자부호           9
# 해외거래처부호     30432
# 특송업체부호      60050
# 수입통관계획코드        0
# 수입신고구분코드        0
# 수입거래구분코드        0
# 수입종류코드          0
# 징수형태코드          0
# 신고중량(KG)        0
# 과세가격원화금액        0
# 운송수단유형코드        0
# 반입보세구역부호        0
# HS10단위부호        0
# 적출국가코드          0
# 원산지국가코드         0
# 관세율구분코드         0
# 관세율             0
# 우범여부            0
# 핵심적발            0
# dtype: int64

# %%
df.groupby('신고중량(KG)').우범여부.mean()
# Out:
# 신고중량(KG)
# 0.1         0.0
# 0.2         0.5
# 0.3         0.5
# 0.4         0.5
# 0.5         1.0
#            ...
# 193561.8    0.0
# 198936.3    0.0
# 209949.6    0.0
# 211852.9    0.0
# 216803.1    0.0
# Name: 우범여부, Length: 64221, dtype: float64

# %%
df.columns
idx=[['우범여부'],['핵심적발']]
idx2 = list(df.columns)
idx2.pop()
idx2.pop()
# Out:
# '우범여부'

# %%
import matplotlib.pyplot as plt

df.corr()
# Out:
#               신고번호   통관지세관부호  수입거래구분코드    수입종류코드    징수형태코드  신고중량(KG)  \
# 신고번호      1.000000 -0.017996 -0.014269  0.018985 -0.005973 -0.014468
# 통관지세관부호  -0.017996  1.000000 -0.001118  0.024190  0.071969  0.062344
# 수입거래구분코드 -0.014269 -0.001118  1.000000 -0.011872  0.044427  0.123261
# 수입종류코드    0.018985  0.024190 -0.011872  1.000000  0.005899 -0.048856
# 징수형태코드   -0.005973  0.071969  0.044427  0.005899  1.000000  0.050980
# 신고중량(KG) -0.014468  0.062344  0.123261 -0.048856  0.050980  1.000000
# 과세가격원화금액  0.011261  0.004244 -0.004088  0.001043 -0.016127  0.012904
# 운송수단유형코드  0.013638  0.001094  0.069654 -0.022332  0.006342  0.210391
# 반입보세구역부호 -0.012131  0.013001  0.014347 -0.001226 -0.026647  0.005975
# HS10단위부호 -0.021527 -0.010275  0.025469 -0.012650  0.011953  0.038028
# 관세율       0.000496 -0.014882 -0.009143 -0.007090 -0.021411  0.001523
# 우범여부      0.000214  0.095085  0.188329  0.031122  0.094117  0.274396
# 핵심적발      0.009205  0.086668  0.190535  0.029347  0.094572  0.257180
#
#           과세가격원화금액  운송수단유형코드  반입보세구역부호  HS10단위부호       관세율      우범여부      핵심적발
# 신고번호      0.011261  0.013638 -0.012131 -0.021527  0.000496  0.000214  0.009205
# 통관지세관부호   0.004244  0.001094  0.013001 -0.010275 -0.014882  0.095085  0.086668
# 수입거래구분코드 -0.004088  0.069654  0.014347  0.025469 -0.009143  0.188329  0.190535
# 수입종류코드    0.001043 -0.022332 -0.001226 -0.012650 -0.007090  0.031122  0.029347
# 징수형태코드   -0.016127  0.006342 -0.026647  0.011953 -0.021411  0.094117  0.094572
# 신고중량(KG)  0.012904  0.210391  0.005975  0.038028  0.001523  0.274396  0.257180
# 과세가격원화금액  1.000000 -0.009608 -0.008090 -0.009501 -0.004411 -0.003535 -0.002963
# 운송수단유형코드 -0.009608  1.000000  0.007213  0.044398  0.011184  0.179240  0.169289
# 반입보세구역부호 -0.008090  0.007213  1.000000  0.005071  0.005223  0.013877  0.014802
# HS10단위부호 -0.009501  0.044398  0.005071  1.000000 -0.251069  0.052778  0.046780
# 관세율      -0.004411  0.011184  0.005223 -0.251069  1.000000  0.005296  0.013202
# 우범여부     -0.003535  0.179240  0.013877  0.052778  0.005296  1.000000  0.937859
# 핵심적발     -0.002963  0.169289  0.014802  0.046780  0.013202  0.937859  1.000000

# %%
df = pd.read_csv('../data/train.csv', encoding = 'utf-8')
평균무게 = df['신고중량(KG)'].mean()
df = df[(df['신고중량(KG)'] >= 평균무게)]
corrdf = df[['신고중량(KG)','우범여부']].corr()

max_corr = corrdf["우범여부"][0]
max_wgt = 평균무게

print("max_corr : %f \nmax_wgt : %f"%(max_corr,max_wgt))

while(평균무게<df['신고중량(KG)'].max()):
    df = df[(df['신고중량(KG)'] >= 평균무게)]
    corrdf = df[['신고중량(KG)','우범여부']].corr()
    if corrdf["우범여부"][0] > max_corr:
        max_corr = corrdf["우범여부"][0]
        max_wgt = 평균무게
    평균무게 += 100

print("max_corr : %f \nmax_wgt : %f"%(max_corr,max_wgt))
# Out:
# max_corr : 0.119856
# max_wgt : 8524.613459
# max_corr : 0.315976
# max_wgt : 23624.613459

# %%
df = pd.read_csv('../data/train.csv', encoding = 'utf-8')
평균무게 = df['신고중량(KG)'].mean()
df = df[(df['신고중량(KG)'] >= 평균무게)]
df
# Out:
#            신고번호        신고일자  통관지세관부호  신고인부호    수입자부호  해외거래처부호  특송업체부호  \
# 1      85092852  2020-01-01       30  305K5  5IS70LE      NaN     NaN
# 2      63014158  2020-01-01       20  CGMT6  GJ5KBL3  R9ZQOG7     NaN
# 3      40175917  2020-01-01       40  QWUTG  PBYW02T      NaN     NaN
# 4      11602631  2020-01-01       30  0X1CO  MCX0GJB  4Z9PX0Y     NaN
# 6      33191755  2020-01-01       40  BTMNQ  I0J35SK  ZKHM0AL  PAVJZL
# ...         ...         ...      ...    ...      ...      ...     ...
# 89280  28363670  2020-11-21       40  QPV57  365ZNAS  6CIGGIP  PAVJZL
# 89293  36396343  2020-11-21       13  OGZCI  PXEEEQM  V4LD98J  1A3HEJ
# 89329  20385308  2020-11-22       20  HOSTX  ZTLS6D2  B7WN42T  L67RFP
# 89332  39577880  2020-11-22       20  9TJBD  SMC66FP  LB7UGY3  VI9G4M
# 89337  40808950  2020-11-22       13  QKEZ0  D6GFJ2I  XID0XWR     NaN
#
#       수입통관계획코드 수입신고구분코드  수입거래구분코드  ...      과세가격원화금액  운송수단유형코드  반입보세구역부호  \
# 1            C        B        11  ...  5.730972e+05        40   4077010
# 2            D        B        11  ...  5.219489e+04        40   4077007
# 3            C        B        94  ...  1.773608e+06        40   4077106
# 4            C        B        11  ...  8.777327e+06        40   2006075
# 6            D        B        11  ...  0.000000e+00        40   2002079
# ...        ...      ...       ...  ...           ...       ...       ...
# 89280        C        B        11  ...  3.661758e+06        40   1602003
# 89293        Z        E        92  ...  1.173109e+05        40   4077001
# 89329        E        B        11  ...  1.380167e+08        40   2006075
# 89332        Z        B        11  ...  0.000000e+00        40   2011642
# 89337        D        D        15  ...  6.878996e+06        10   4077005
#
#          HS10단위부호  적출국가코드  원산지국가코드  관세율구분코드   관세율 우범여부 핵심적발
# 1      2106909099      US       US        A   8.0    0    0
# 2      6307909000      US       US        A  10.0    0    0
# 3      6505009090      CN       CN        A   8.0    0    0
# 4      6204320000      CN       CN     FCN1   5.2    1    1
# 6      3915909000      JP       JP        C   6.5    0    0
# ...           ...     ...      ...      ...   ...  ...  ...
# 89280  6201931000      VN       VN     FVN1   0.0    0    0
# 89293  8471300000      CA       CN        C   0.0    1    2
# 89329  8703231010      DE       DE     FEU1   0.0    1    1
# 89332  6309000000      MY       MY        A   8.0    1    2
# 89337  8538909000      VN       KR        A   8.0    0    0
#
# [26810 rows x 23 columns]

# %%
df = pd.read_csv('../data/train.csv', encoding = 'utf-8')
corrdf = df[['신고중량(KG)','우범여부']].corr()
corrdf
# Out:
#           신고중량(KG)      우범여부
# 신고중량(KG)  1.000000  0.006847
# 우범여부      0.006847  1.000000

# %%
df = pd.read_csv('../data/train.csv', encoding = 'utf-8')
평균무게 = df['신고중량(KG)'].mean()
df = df[(df['신고중량(KG)'] < 평균무게)]
corrdf = df[['신고중량(KG)','우범여부']].corr()

max_corr = corrdf["우범여부"][0]
max_wgt = 평균무게

print("max_corr : %f \nmax_wgt : %f"%(max_corr,max_wgt))

while(평균무게>df['신고중량(KG)'].min()):
    df = df[(df['신고중량(KG)'] < 평균무게)]
    corrdf = df[['신고중량(KG)','우범여부']].corr()
    if (corrdf["우범여부"][0] > max_corr) or (corrdf['우범여부'][0]>max_corr * -1):
        max_corr = corrdf["우범여부"][0]
        max_wgt = 평균무게
    평균무게 -= 100

print("max_corr : %f \nmax_wgt : %f"%(max_corr,max_wgt))
# Out:
# max_corr : -0.101005
# max_wgt : 8524.613459
# max_corr : 0.027040
# max_wgt : 24.613459
