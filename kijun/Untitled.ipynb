# %%
import pandas as pd

df = pd.read_csv('../data/test.csv')
df
# Out:
#            신고번호        신고일자  통관지세관부호  신고인부호    수입자부호  해외거래처부호  특송업체부호  \
# 0      87601405  2020-11-23       30  QPV57  ANDWSFE  NVELOBJ     NaN
# 1      49428483  2020-11-23       20  9AYQ5  0FWTLQC  93SPF0B     NaN
# 2      67484911  2020-11-23       40  5CBJ1  RNVXTRN  BON3KQF     NaN
# 3      42803508  2020-11-23       20  1HUE4  PWUIU5M  DIH9NVE  9BO2S9
# 4      34214927  2020-11-23       40  QPV57  ET2AJPR  F7P1I30     NaN
# ...         ...         ...      ...    ...      ...      ...     ...
# 10520  33357888  2020-12-31       40  QPV57  2OWH6M7  I0MG4ZH     NaN
# 10521  14455915  2020-12-31       13  F57Z2  35JHADJ  40P9B1W  QJ0YGH
# 10522  83923494  2020-12-31       40  4TYA6  OEYQJDQ      NaN     NaN
# 10523  17890784  2020-12-31       30  CGMT6  V69LHEI      NaN  PR5UFJ
# 10524  99164173  2020-12-31       16  HY5FQ  FUQRKQL  W46PYSV  YGHZ0X
#
#       수입통관계획코드 수입신고구분코드  수입거래구분코드  ...  징수형태코드  신고중량(KG)      과세가격원화금액  \
# ...
