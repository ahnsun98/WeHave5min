# %%
import pandas as pd

train_df = pd.read_csv('../data/train.csv', encoding='utf-8')
test_df = pd.read_csv('../data/test.csv', encoding='utf-8')

# %%
train_df.head()
# Out:
#      신고번호        신고일자  통관지세관부호  신고인부호    수입자부호  해외거래처부호  특송업체부호 수입통관계획코드  \
# 0   37453  2020-01-01       40  10UUA  435E04J  CFLCEFM     NaN        C
# 1  150339  2020-01-01       20  7E3BD  1NTJ7F6      NaN     NaN        C
# 2   55710  2020-01-01       10  QHZ00  DGHPNRA  ZEXKR7K  8W5SEL        F
# 3  413154  2020-01-01       20  SZIVC  G85A4OI  WD62ULK  0X6YQV        C
# 4  223511  2020-01-01       40  BU7II  9I00BFP  Q22MMTW     NaN        F
#
#   수입신고구분코드  수입거래구분코드  ...      과세가격원화금액  운송수단유형코드  반입보세구역부호    HS10단위부호  \
# 0        A        15  ...  1.207812e+04        40   4077180  4202999000
# 1        B        15  ...  5.938688e+05        10   4002001  9503003919
# 2        B        94  ...  6.238490e+04        40  15002001  8708290000
# 3        B        15  ...  4.321373e+06        10   4002001  2933699099
# 4        B        15  ...  1.212105e+06        10   2002079  6205200000
#
#    적출국가코드  원산지국가코드  관세율구분코드   관세율 우범여부 핵심적발
# 0      CN       CN        A   8.0    0    0
# 1      CN       CN        A   8.0    0    0
# 2      CN       CN     FCN1   3.2    1    2
# 3      CN       CN     FCN1   0.0    0    0
# 4      CN       CN        A  13.0    0    0
#
# [5 rows x 23 columns]

# %%
test_df.head()
# Out:
#      신고번호        신고일자  통관지세관부호  신고인부호    수입자부호  해외거래처부호 특송업체부호 수입통관계획코드  \
# 0  982834  2020-11-23       20  KWGEB  B7FVPTT  0TSA7K7    NaN        F
# 1  828961  2020-11-23       40  6KGOC  5O4D6XE      NaN    NaN        E
# 2  522066  2020-11-23       40  F8UY6  X71K5VO      NaN    NaN        C
# 3  999547  2020-11-23       16  IK9DK  VOA8M3S      NaN    NaN        C
# 4  919320  2020-11-23       10  R716N  205JY8P      NaN    NaN        C
#
#   수입신고구분코드  수입거래구분코드  ...  징수형태코드  신고중량(KG)      과세가격원화금액  운송수단유형코드  반입보세구역부호  \
# 0        B        15  ...      11    3731.9  2.755287e+06        40   3012343
# 1        B        94  ...      11    6406.5  8.517864e+05        40   4077106
# 2        B        11  ...      11    5824.9  6.532926e+04        40   4002001
# 3        B        11  ...      11    3798.3  1.028587e+06        40   2011007
# 4        B        11  ...      11    3795.7  1.677178e+06        40   1011182
#
#      HS10단위부호  적출국가코드 원산지국가코드 관세율구분코드   관세율
# 0   712909000      US      US       A  27.0
# 1  9703001000      US      US       A   0.0
# 2  2106909099      US      US       A   8.0
# 3  1207999000      US      US       A   3.0
# 4  8711201000      VN      VN    FVN1   0.0
#
# [5 rows x 21 columns]

# %%
train_df.isnull().sum()
# Out:
# 신고번호            0
# 신고일자            0
# 통관지세관부호         0
# 신고인부호           0
# 수입자부호           0
# 해외거래처부호     26653
# 특송업체부호      59832
# 수입통관계획코드        0
# 수입신고구분코드        0
# 수입거래구분코드        0
# 수입종류코드          0
# 징수형태코드          0
# 신고중량(KG)        0
# 과세가격원화금액        0
# 운송수단유형코드        0
# 반입보세구역부호        0
# HS10단위부호        0
# 적출국가코드          0
# 원산지국가코드         0
# 관세율구분코드         0
# 관세율             0
# 우범여부            0
# 핵심적발            0
# dtype: int64

# %%
train_df["우범여부"].value_counts()
# Out:
# 0    69836
# 1    19783
# Name: 우범여부, dtype: int64

# %%
train_df["핵심적발"].value_counts()

# 0:우범x, 1:우범-일반, 2:우범-핵심
# Out:
# 0    69836
# 2    10224
# 1     9559
# Name: 핵심적발, dtype: int64

# %% [markdown]
# ### 랜덤포레스트 모델 (의사결정트리+앙상블기법)
# ### 원핫인코더

# %%
import re
from sklearn.preprocessing import LabelEncoder #트리관련 ML은 ㄱㅊ
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import mglearn

# %%
def label_encoder(items):
    encoder = LabelEncoder()
    encoder.fit(items)
    labels = encoder.transform(items)
    print('인코딩 변환값:',labels)
    classes = encoder.classes_
    print('인코딩 클래스:',classes)
    return labels, classes

# %%
def data_preprocessing():
    X = train_df.iloc[:, :-2]
    y = train_df.iloc[:, -1:]
    X['신고일자'] = list(map(lambda x : re.sub('[^0-9]+', '', x), X['신고일자']))
    labels, classes = label_encoder(X['신고인부호'])
    X['신고인부호'] = labels
    labels, classes = label_encoder(X['수입자부호'])
    X['수입자부호'] = labels
    labels, classes = label_encoder(X['해외거래처부호'])
    X['해외거래처부호'] = labels
    labels, classes = label_encoder(X['특송업체부호'])
    X['특송업체부호'] = labels
    X['수입통관계획코드'] = list(map(lambda x : ord(x), X['수입통관계획코드']))
    X['수입신고구분코드'] = list(map(lambda x : ord(x), X['수입신고구분코드']))
    labels, classes = label_encoder(X['적출국가코드'])
    X['적출국가코드'] = labels
    labels, classes = label_encoder(X['원산지국가코드'])
    X['원산지국가코드'] = labels
    labels, classes = label_encoder(X['관세율구분코드'])
    X['관세율구분코드'] = labels

# %%
# def get_dataset():
#     X = train_df1.iloc[:, :-2]
#     X['신고일자'] = list(map(lambda x : re.sub('[^0-9]+', '', x), X['신고일자']))
#     X = X.drop(columns=['신고인부호', '수입자부호', '해외거래처부호', '특송업체부호', '관세율구분코드', '적출국가코드', '원산지국가코드', '수입통관계획코드', '수입신고구분코드'])
#     y = train_df1.iloc[:, -1:]
    
#     X_train, X_test , y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=1)
#     return X_train, X_test, y_train, y_test

# %%
data_preprocessing()
X_train, X_test , y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=1)
# Out:
# 인코딩 변환값: [ 26 200 714 ... 714 706  46]
# 인코딩 클래스: ['024XU' '0384L' '04EUR' '06-Mar-02' '06KJK' '08KC3' '09LR7' '0AROV'
#  '0BRX7' '0DTE5' '0GF7E' '0GFP5' '0GJ42' '0JLRB' '0JSOG' '0K9VP' '0M9XO'
#  '0MV89' '0N4B6' '0P4GW' '0P51R' '0Q91O' '0R70F' '0U5WV' '0UHM6' '0VQ74'
#  '10UUA' '11IPX' '12L2I' '16QHA' '18IB5' '195UI' '1DSMW' '1EQBB' '1FCBY'
#  '1GHRE' '1HWHH' '1I4UX' '1IE9Q' '1IXZC' '1J66L' '1KULV' '1NSBL' '1OPWE'
#  '1PPW4' '1SHHM' '1UIAW' '1US35' '1YNAV' '217VL' '21VYO' '29LR4' '2AKRK'
#  '2C3UP' '2EAKB' '2HCPY' '2HNO8' '2J4W2' '2JB1F' '2JH2C' '2JKON' '2K0S6'
#  '2KDRU' '2KHVO' '2LU5I' '2NZLO' '2Q003' '2R0GI' '2RW6E' '2S1UP' '2SO79'
#  '2T6VY' '2T75C' '2TK79' '2UAHM' '2VBI7' '2VKJR' '2VXLA' '2Z64X' '2ZSVR'
#  '321JP' '3223L' '32GCY' '32J2G' '33CFU' '35ZBQ' '384YE' '38GS0' '3CHCK'
#  '3ECHR' '3ECUC' '3EOA1' '3GT9C' '3HKFB' '3JVOE' '3LZ8V' '3O1UK' '3QCF2'
#  '3QGAV' '3RFJ9' '3S1UP' '3SHE1' '3TP3X' '3UAA4' '3X8IE' '3X9ZP' '3ZP28'
#  '3ZYL2' '4057T' '416XE' '418RI' '41HYY' '41VJ5' '42CAK' '49U97' '49Y1E'
#  '4BSPF' '4C65V' '4DFT4' '4FWGN' '4GWP5' '4GXQM' '4JBQG' '4JMQA' '4JS7L'
#  '4L7ZV' '4LETZ' '4M21C' '4M7TR' '4NN2I' '4NVQX' '4O3B1' '4OPZT' '4PPZC'
#  '4QKMC' '4RIXP' '4RNPB' '4TTDJ' '4W6H2' '4XIOO' '4XV3N' '50DP5' '50NE6'
#  '52ACL' '52NET' '52UJL' '5A1J9' '5AAUP' '5D3ON' '5EFOS' '5GNMG' '5I83A'
#  '5I9GV' '5MV6J' '5Q0CU' '5Q246' '5R9HF' '5SUGS' '5SWX5' '5V27W' '5VMHG'
#  '5XOH6' '67OVQ' '67VRT' '67Y7H' '6AM8L' '6B3W2' '6BDYX' '6DTE6' '6E3MB'
#  '6EZM5' '6FKHF' '6HZN1' '6KGOC' '6KKKN' '6L8XV' '6MJSY' '6OHYU' '6P8QL'
#  '6RGGV' '6T7JO' '6TI0O' '6TYJM' '6WBLW' '6WDJ5' '6YZT1' '6ZAX9' '6ZEY4'
#  '6ZJQO' '6ZJQQ' '70PHV' '71QSL' '71TOI' '74VH1' '76BYY' '779QS' '77MVL'
#  '7B3MH' '7DCLA' '7DJSR' '7E3BD' '7F5Q6' '7GJB8' '7HHQL' '7MLJQ' '7NW8I'
#  '7QFO9' '7SBOC' '7SRWA' '7SVJY' '7TXD7' '7V9QD' '7WE38' '7XXE4' '7ZVU5'
#  '808WN' '80HI3' '810NA' '840N8' '86E9A' '88RTC' '89304' '8DYFX' '8G8I1'
#  '8GPS2' '8H5DR' '8IETN' '8J8UN' '8JDU7' '8NCJF' '8Q952' '8SAOG' '8T9T2'
#  '8UHCX' '91YO8' '920BK' '929AG' '92LRF' '92XQC' '951BK' '95A1G' '95WSZ'
#  '964CV' '97YYA' '99G4W' '99KAT' '9AAS1' '9BYFN' '9CFVI' '9CY62' '9F3OB'
#  '9FV58' '9GCLZ' '9HAMY' '9J5PC' '9QEQ6' '9S8MV' '9T9CJ' '9TN2B' '9X6GF'
#  '9YIWB' '9YJJ9' 'A0M10' 'A0QZG' 'A0YEC' 'A2OWG' 'A3NQL' 'A6NU4' 'AAYEP'
#  'AB5Z6' 'ABRVJ' 'ADGRK' 'AGG9R' 'AH6UG' 'AKD2M' 'ALNO1' 'AM9L7' 'AN3NU'
#  'ANQCJ' 'AP5VO' 'AQDXB' 'AQXHG' 'ASYF4' 'AUNF2' 'AVS08' 'AXMK5' 'AZ52K'
#  'B1DFX' 'B2UGK' 'B3BOY' 'B4PYW' 'B54RA' 'B7UDA' 'B9OEA' 'B9Y0D' 'BCWG2'
#  'BE5KZ' 'BHQ0J' 'BR9KK' 'BRKYG' 'BU13S' 'BU7II' 'BV4ZA' 'BV8MR' 'BXAS8'
#  'BYBQF' 'C0F03' 'C1MB5' 'C2000' 'C38CX' 'C6WC7' 'C8I99' 'C8UY6' 'C97AQ'
#  'CAVNZ' 'CC4BL' 'CFMAK' 'CG8YN' 'CHOIY' 'CLSND' 'CMPV7' 'CQA23' 'CR5WE'
#  'CRGSB' 'CRV4G' 'CSJ3M' 'CUDHS' 'CWHD1' 'CXS87' 'CZ33C' 'CZ4HY' 'D11QS'
#  'D15UX' 'D4E8X' 'D75C2' 'D826J' 'D8ZXK' 'D9FLN' 'DA0XP' 'DA6C8' 'DAKKG'
#  'DCQ06' 'DCZAA' 'DEPLC' 'DJWQ8' 'DMM92' 'DN9V1' 'DOQTA' 'DP3SL' 'DQZRG'
#  'DRONU' 'DSN1F' 'DU0FM' 'DU32S' 'DUISL' 'DUZIV' 'DWNKT' 'DXA1V' 'E22KQ'
#  'E4X2A' 'E6RU2' 'E97F6' 'E9DBH' 'EBD1A' 'EFZCY' 'EG1AB' 'EHF3W' 'EIGGT'
#  'EK021' 'EKFW2' 'EL6PI' 'ELB6K' 'EOFS2' 'EOWZF' 'EOX03' 'EOYD1' 'EPO4R'
#  'EQ6TS' 'ESN3X' 'ET5XS' 'EXCIR' 'EXDO6' 'F0GXU' 'F1NNV' 'F1VOO' 'F386X'
#  'F39X1' 'F4KRU' 'F4T3M' 'F5F9S' 'F60IB' 'F6JBF' 'F7OLA' 'F8UY6' 'F9OYA'
#  'FB5QA' 'FCIF0' 'FF9QS' 'FHMSP' 'FHX3G' 'FL1GF' 'FLWKF' 'FN5BN' 'FNG7M'
#  'FNRFO' 'FO4OQ' 'FO8NX' 'FOWBO' 'FRAHI' 'FT4NK' 'FT8IR' 'FVFS1' 'FWWE2'
#  'FXC74' 'FXGI3' 'FYDEP' 'G2E08' 'G4JD4' 'G4SF1' 'G5HR5' 'G7I9B' 'G8PUG'
#  'G936J' 'G9B37' 'GA78Z' 'GBG8O' 'GC43Z' 'GCDFW' 'GCQH9' 'GCRGM' 'GD0TZ'
#  'GFCOP' 'GFRUH' 'GH7VI' 'GIUEX' 'GL5W1' 'GLXVJ' 'GNF3D' 'GPC8X' 'GQ4CV'
#  'GSKPD' 'GTGMT' 'GTTI7' 'GVBS8' 'GVZZL' 'GYE2C' 'GZ38P' 'GZB7K' 'GZD4L'
#  'H0UQX' 'H1HB2' 'H2L9Q' 'H3J22' 'H4A1P' 'H5KNB' 'H70A3' 'H80YI' 'H82VS'
#  'HBF67' 'HBLMV' 'HCRJB' 'HCWAP' 'HD72H' 'HDXF2' 'HGUWF' 'HH0IE' 'HIJ6Q'
#  'HJM3O' 'HJX6F' 'HK2M2' 'HKDCQ' 'HLPW1' 'HLWMT' 'HR17R' 'HRIE1' 'HX00E'
#  'HYZG9' 'I0A5Z' 'I1FUG' 'I1QTA' 'I271A' 'I9P6X' 'IB5RF' 'IBW02' 'IC657'
#  'ICBTH' 'IETPR' 'IF0FK' 'IF3P0' 'IF7ED' 'IFIQU' 'IFJ6G' 'IG6KL' 'IGKUY'
#  'IH30L' 'II32E' 'IITMX' 'IK9DK' 'ILHAD' 'IMEBB' 'IQV4O' 'IR84X' 'IT557'
#  'IUNNX' 'IVJZL' 'IW92Y' 'IXE15' 'IXIFS' 'IXNCJ' 'J0A56' 'J5PFV' 'J6QI0'
#  'J7ZMH' 'J8DK6' 'J8VN5' 'JAF5R' 'JBRQF' 'JC7C2' 'JHCUD' 'JHR57' 'JJBDX'
#  'JM53U' 'JMOG1' 'JNGZF' 'JP65B' 'JPQ2C' 'JQ4T4' 'JRBTK' 'JTAJD' 'JTZJG'
#  'JUJMU' 'JUL1B' 'JVCQU' 'JX0VZ' 'JYONP' 'K0BWZ' 'K0DHF' 'K1DXI' 'K6R95'
#  'K7S1V' 'KDAD8' 'KGGUX' 'KGO6O' 'KGPVX' 'KJ7UU' 'KK2HF' 'KNPFB' 'KNVQM'
#  'KPHQ0' 'KR6Q9' 'KTALB' 'KVDX5' 'KWGEB' 'KYDGW' 'KZJQ6' 'L0E4R' 'L0FEL'
#  'L0H0O' 'L14UX' 'L1Y74' 'L23PC' 'L2DMY' 'L2GQI' 'L2WHI' 'L701Y' 'L9AYA'
#  'LAMYK' 'LB83A' 'LBDGH' 'LCR3X' 'LCTWK' 'LDFTP' 'LDM3A' 'LE8TH' 'LFFG3'
#  'LFNDP' 'LHNIB' 'LIP35' 'LJ0IG' 'LJO5G' 'LLVS3' 'LO79N' 'LOLUP' 'LP4Q4'
#  'LSA1T' 'LTUEQ' 'LXDTK' 'LXGH7' 'M0X3I' 'M4KNR' 'M5P03' 'M786U' 'M7VP8'
#  'M7Z80' 'M8TMF' 'M9V2Y' 'MA9RP' 'MAJ6G' 'MBPE7' 'MF91Q' 'MFH9Z' 'MH4YM'
#  'MLRW0' 'MMTCI' 'MMYQ9' 'MPMQJ' 'MPSVC' 'MS5HV' 'MS6NT' 'MT5Q0' 'MTSGL'
#  'MWN35' 'MZ43F' 'N01YA' 'N02H6' 'N10LW' 'N4RV7' 'N533L' 'N6F1U' 'N6NHR'
#  'N85U8' 'N8SJP' 'N97Q7' 'NCDVO' 'ND288' 'NI4WI' 'NKADR' 'NKZ7L' 'NP5J9'
#  'NPDHO' 'NPEGP' 'NPK6E' 'NQ2R0' 'NRZBI' 'NSAMT' 'NSZNP' 'NU1BX' 'NURF1'
#  'NXQ31' 'NXTRZ' 'O0HE9' 'O2T3V' 'O3XW5' 'O820Y' 'O9AZ7' 'OC7YM' 'OE3VU'
#  'OEC63' 'OECKJ' 'OEHCI' 'OGB47' 'OIB7L' 'OJOY4' 'OK4LV' 'OK5W0' 'OKHWP'
#  'OM56H' 'OP2J7' 'OP9GQ' 'OPJYW' 'OR2WX' 'OUSSW' 'OVDP5' 'OXCIA' 'OY8X7'
#  'OYVPF' 'OZEOQ' 'OZRIX' 'P15QT' 'P228Y' 'P3SJC' 'P56OT' 'P6H61' 'P6X8R'
#  'P77KK' 'P7MA0' 'P8PQ8' 'P8Y67' 'P91V6' 'PBSDO' 'PC3Q1' 'PCP5G' 'PDWOI'
#  'PF6UK' 'PGKT0' 'PGSAJ' 'PHD1D' 'PHYZI' 'PI9P0' 'PJ3OE' 'PKTJZ' 'PMPY5'
#  'POIVL' 'POMKO' 'PP4JQ' 'PQH8E' 'PRFAB' 'PS726' 'PVYBQ' 'PWA11' 'PXWKC'
#  'PY0C3' 'PYLNT' 'Q431H' 'Q739Y' 'Q745I' 'Q9VMK' 'QBHFY' 'QDCP1' 'QEX7C'
#  'QFJZR' 'QGKE8' 'QHSRH' 'QHYLX' 'QHZ00' 'QKPY9' 'QKVZO' 'QMCCG' 'QO5FA'
#  'QP2CK' 'QSVYF' 'QUAZZ' 'QV2S9' 'QWCSW' 'QY0LZ' 'QZH1H' 'R0JIZ' 'R1C3E'
#  'R3EPF' 'R457G' 'R4BPE' 'R5Q2B' 'R716N' 'R86QT' 'R8ICG' 'RBNZV' 'RDVDE'
#  'REODJ' 'RFQ0M' 'RISFL' 'RKA0U' 'RL2TD' 'RM5UA' 'RMJ53' 'RMVRZ' 'ROE0J'
#  'ROKBV' 'RPBKG' 'RPDSX' 'RPT7Y' 'RPUV9' 'RQRMZ' 'RSGG5' 'RU9S3' 'RUKI1'
#  'RVVVN' 'RYHC9' 'S06TP' 'S1681' 'S1M1A' 'S2D1Y' 'S2V7K' 'S33OE' 'S3UT2'
#  'S4360' 'SAYRG' 'SBD21' 'SDLER' 'SEYOK' 'SFLNA' 'SFZML' 'SHGTK' 'SL3O1'
#  'SMDUO' 'SMOGD' 'SP7JT' 'SRM2U' 'SUB9T' 'SULQZ' 'SZIVC' 'T1L29' 'T21Y8'
#  'T9WPZ' 'TAWUS' 'TB2UB' 'TCP7I' 'TEUKM' 'TEY4M' 'THKIP' 'THP2G' 'TIM11'
#  'TJY4M' 'TPHDM' 'TSA9U' 'TSNOY' 'TTUGK' 'TUP09' 'TWH3J' 'TY4MV' 'TZ3Z6'
#  'TZQX3' 'U1STC' 'U26F2' 'U2KHB' 'U39PI' 'U3E7G' 'U5V58' 'U7NLF' 'U7ZGP'
#  'U8FBG' 'UBBB1' 'UCKQ7' 'UEUWX' 'UGFRL' 'UHTIN' 'UHW0F' 'UHYCV' 'UIF5C'
#  'UIG8U' 'UNJ7Q' 'UO2KQ' 'UOZUA' 'USYLW' 'UUXBY' 'UV0TR' 'UWN9O' 'UX36C'
#  'UZMLA' 'V0Q35' 'V0RVL' 'V4QLS' 'V58AO' 'V71H1' 'V83GQ' 'VIGF0' 'VKP4W'
#  'VKX8Y' 'VKZZ2' 'VLD87' 'VN4AX' 'VNML2' 'VPMDM' 'VT2N6' 'VV9JE' 'VYGH7'
#  'VYPIZ' 'W0BK9' 'W1CW6' 'W2P5I' 'W3G7Z' 'W3L06' 'W44B0' 'W5JHR' 'W7ADM'
#  'W7JZ1' 'W7LX2' 'W9NUT' 'WB464' 'WCG7A' 'WE806' 'WEBDO' 'WF4IB' 'WG28G'
#  'WH4ZH' 'WI9FK' 'WM4TP' 'WP5MQ' 'WPU4L' 'WWBXQ' 'WWLO5' 'WWP4G' 'WWU72'
#  'WY92A' 'X0FF2' 'X0SIM' 'X3X82' 'X7Y19' 'X8XRN' 'X9F72' 'XAL3H' 'XDTAW'
#  'XHTBP' 'XL864' 'XLQZ1' 'XLUT3' 'XOP9A' 'XPPX8' 'XQBMA' 'XRV47' 'XS6VY'
#  'XUEFW' 'XVHLL' 'XW4RC' 'XWUWM' 'Y2CEG' 'Y4Z64' 'Y58LL' 'Y5KX9' 'Y7261'
#  'YAFER' 'YBJP6' 'YBP6A' 'YCGQC' 'YD60V' 'YDYXG' 'YEIGJ' 'YEX2P' 'YH6R7'
#  'YM1UV' 'YQ5ZN' 'YQ659' 'YRXKL' 'YUE2V' 'YUI5J' 'Z010A' 'Z0FAB' 'Z10KS'
#  'Z13T7' 'Z1WD1' 'Z2DY5' 'Z7IHS' 'Z87CC' 'Z8B9Q' 'Z9RWG' 'ZA1LS' 'ZBFE4'
#  'ZDOIW' 'ZFZU1' 'ZG70F' 'ZJ5S6' 'ZK6TG' 'ZKHJA' 'ZLR9M' 'ZMSSC' 'ZPDR7'
#  'ZPLUJ' 'ZQRNE' 'ZRMVP' 'ZRO17' 'ZTE0X' 'ZYJ1H' 'ZYTZN' 'ZZ72T' 'ZZOC2']
# 인코딩 변환값: [ 953  396 3141 ... 2035 6616 7920]
# 인코딩 클래스: ['001LIJ3' '00A2466' '00Q8E3W' ... 'ZZSPW0G' 'ZZTL647' 'ZZW5HXG']
# 인코딩 변환값: [1585 4643 4577 ... 2264 4146 1734]
# 인코딩 클래스: ['007UPS1' '00RWF7U' '0105Q3U' ... 'ZZA1AZP' 'ZZCVYCA' nan]
# 인코딩 변환값: [89 89 28 ... 75 75 89]
# 인코딩 클래스: ['07T2SZ' '0S5ZS6' '0X6YQV' '0XZTE1' '1CHM5E' '1L6OMK' '1P4NZE' '1UJTSZ'
#  '1UKGV1' '1YXDGZ' '22DM56' '2BSKZU' '2IX3UI' '2TNP07' '3G22A7' '3GPEI4'
#  '4D5LN1' '4HATLQ' '4QQP89' '50AP6R' '58ZEWA' '5DQ2Y8' '5TXX73' '7F40SK'
#  '7ZK3JU' '881B97' '8HWJ75' '8QCBM4' '8W5SEL' '92BE4B' '995X1O' '9PS8C1'
#  '9YFPVN' 'A8SIA3' 'AT0EAG' 'B1IF66' 'BQDJSK' 'C5P74O' 'CABUQY' 'CF3M0C'
#  'DKBD7G' 'E1VDCW' 'EPMYSL' 'FBZP2E' 'FHLZZW' 'FLCQAX' 'G19AU9' 'GBRB8C'
#  'GJS96M' 'GJZ4QI' 'H0B5AS' 'HIOX3V' 'HYXXHV' 'IF71MR' 'IJT1QU' 'IMMGG2'
#  'JA291F' 'JJH0LY' 'JMAY90' 'JZAYKA' 'LW08GG' 'MJ52NM' 'MVKPWV' 'NP5BYM'
#  'NXIGI1' 'O7H6GH' 'OACUA7' 'QKVTIF' 'S86JST' 'SAC4VX' 'SGF26F' 'SP0VA4'
#  'ST0RNX' 'SW8R85' 'UF2HOK' 'V18W2M' 'V3WAEZ' 'WLAF1T' 'WLXSQO' 'WVTM1M'
#  'WY0HAG' 'X3FQMW' 'XLWR4F' 'Y7M94D' 'YNRX1F' 'YUXEME' 'Z8612H' 'ZDTFUZ'
#  'ZXTR60' nan]
# 인코딩 변환값: [15 15 15 ... 81 31 15]
# 인코딩 클래스: ['AE' 'AL' 'AR' 'AT' 'AU' 'AZ' 'BD' 'BE' 'BH' 'BR' 'CA' 'CF' 'CH' 'CL'
#  'CM' 'CN' 'CO' 'CR' 'CZ' 'DE' 'DK' 'DO' 'EE' 'EG' 'ES' 'FI' 'FR' 'GB'
#  'GN' 'GR' 'GT' 'HK' 'HU' 'ID' 'IE' 'IL' 'IN' 'IT' 'JP' 'KH' 'KR' 'LA'
#  'LK' 'LR' 'LT' 'LU' 'LV' 'MA' 'MM' 'MN' 'MR' 'MT' 'MX' 'MY' 'NG' 'NL'
#  'NO' 'NP' 'NZ' 'OM' 'PA' 'PE' 'PH' 'PK' 'PL' 'PT' 'QA' 'RO' 'RU' 'SA'
#  'SB' 'SE' 'SG' 'SI' 'SN' 'SY' 'TH' 'TL' 'TR' 'TW' 'UA' 'US' 'UZ' 'VN'
#  'ZA' 'ZZ']
# 인코딩 변환값: [19 19 19 ... 95 19 19]
# 인코딩 클래스: ['AE' 'AF' 'AL' 'AM' 'AT' 'AU' 'BA' 'BD' 'BE' 'BG' 'BH' 'BR' 'BW' 'BY'
#  'CA' 'CF' 'CH' 'CL' 'CM' 'CN' 'CO' 'CR' 'CZ' 'DE' 'DK' 'DO' 'EE' 'EG'
#  'ES' 'FI' 'FR' 'GB' 'GH' 'GN' 'GT' 'GU' 'HK' 'HN' 'HR' 'HU' 'ID' 'IE'
#  'IL' 'IN' 'IR' 'IT' 'JP' 'KG' 'KH' 'KR' 'LA' 'LK' 'LR' 'LT' 'LU' 'LV'
#  'MA' 'MD' 'MM' 'MN' 'MR' 'MT' 'MX' 'MY' 'NG' 'NL' 'NO' 'NP' 'NZ' 'OM'
#  'PA' 'PE' 'PH' 'PK' 'PL' 'PT' 'QA' 'RO' 'RU' 'SB' 'SE' 'SG' 'SI' 'SK'
#  'SL' 'SN' 'SV' 'SY' 'TH' 'TL' 'TN' 'TR' 'TT' 'TW' 'UA' 'US' 'UZ' 'VN'
#  'ZA' 'ZZ']
# 인코딩 변환값: [ 0  0 13 ...  1  1 13]
# 인코딩 클래스: ['A' 'C' 'C3' 'CIT' 'CIT1' 'CIT2' 'E1' 'F' 'FAS1' 'FAS4' 'FAU1' 'FCA1'
#  'FCL1' 'FCN1' 'FCN2' 'FCN6' 'FCO1' 'FEF1' 'FEU1' 'FIN1' 'FNZ1' 'FPE1'
#  'FPE2' 'FSG1' 'FTR1' 'FUS1' 'FUS2' 'FUS5' 'FUS6' 'FVN1' 'L' 'P1' 'P3' 'R'
#  'W1' 'W2']

# %%
X_train.head()
# Out:
#          신고번호      신고일자  통관지세관부호  신고인부호  수입자부호  해외거래처부호  특송업체부호  수입통관계획코드  \
# 53791  262101  20200708       10    608   7035     4643      89        67
# 81888  244817  20201023      120    174   4165     3561      89        67
# 59286  128591  20200727       40    216   1594     1323      89        67
# 66714   79506  20200824       33    247   8368      606      14        67
# 3636   405582  20200113      131    381   1680     1552      39        69
#
#        수입신고구분코드  수입거래구분코드  ...  징수형태코드  신고중량(KG)      과세가격원화금액  운송수단유형코드  \
# 53791        66        94  ...      11    5099.9  4.792144e+05        10
# 81888        66        11  ...      11    2928.2  2.936010e+05        10
# 59286        66        15  ...      11    3483.0  5.557387e+06        10
# 66714        66        91  ...      21    3432.0  3.464596e+04        10
# 3636         66        11  ...      18    5843.0  1.325641e+07        10
#
#        반입보세구역부호    HS10단위부호  적출국가코드  원산지국가코드  관세율구분코드   관세율
# 53791   1602003  8708290000      83       97        0   8.0
# 81888   2006023  7117199000      38       30        0   8.0
# 59286   4077008  1901101010      19       23        0  36.0
# 66714   3012312  4016999000      19       23       18   0.0
# 3636    2006087  8471802000      31       19        1   0.0
#
# [5 rows x 21 columns]

# %%
X_test
# Out:
#            신고번호      신고일자  통관지세관부호  수입거래구분코드  수입종류코드  징수형태코드  신고중량(KG)  \
# 67153  56458804  20200824       40        91      21      43    4718.0
# 41771  64425212  20200521       40        96      21      43    4018.2
# 5387   47734257  20200116       80        11      21      11    3940.7
# 57571  95067668  20200720       12        86      21      11    1953.3
# 1286   52721308  20200106       13        11      21      11    5285.0
# ...         ...       ...      ...       ...     ...     ...       ...
# 34563  54986663  20200423      140        11      21      13    6804.0
# 13916  89653615  20200212       16        15      26      14    1111.0
# 31758  34737796  20200413       40        11      21      14      31.7
# 22483  29004606  20200309       40        87      21      18   15718.3
# 87010  19393071  20201111       30        91      21      14      38.4
#
#            과세가격원화금액  운송수단유형코드  반입보세구역부호    HS10단위부호  관세율
# 67153  1.182714e+07        40   8107003  2933399090  0.0
# 41771  4.823038e+05        10   2077002  8203201000  8.0
# 5387   9.204759e+05        10   2010360  6506100000  3.2
# 57571  5.653528e+05        10   4077132  4601949000  0.0
# 1286   1.963488e+05        40   3099999  3004909900  8.0
# ...             ...       ...       ...         ...  ...
# 34563  8.762021e+05        10   3078001  2204211000  0.0
# 13916  2.304417e+05        30  12006008  6806102000  4.8
# 31758  3.159842e+03        30   2086167  4013909010  0.0
# 22483  1.574912e+06        40   3070141  9025191000  0.0
# 87010  2.090410e+04        40   8011138  4803001000  0.0
#
# [6168 rows x 12 columns]

# %%
y_train
# Out:
#        핵심적발
# 30792     2
# 88685     2
# 67382     2
# 36697     0
# 67014     0
# ...     ...
# 77358     0
# 49658     0
# 40977     0
# 28440     0
# 31391     0
#
# [18503 rows x 1 columns]

# %%
forest = RandomForestClassifier(n_estimators=20, max_depth=10, random_state=1)
forest.fit(X_train,np.ravel(y_train))

predict = forest.predict(X_test)
print(accuracy_score(y_test,predict))
# Out:
# 0.5283722438391699

# %%
predict_df = pd.DataFrame(predict)
predict_df.value_counts()
# Out:
# 0    5541
# 2     504
# 1     123
# dtype: int64

# %%
predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
신고번호 = X_test.iloc[:, 0]
신고번호.reset_index(drop=True, inplace=True)

li = []
for x in predict:
    if x == 0:
        li.append(0)
    else:
        li.append(1)
우범여부 = pd.DataFrame(li)
        
Result = pd.concat([신고번호, 우범여부, predict_df], axis=1)
Result.columns = ['신고번호', '우범여부', '핵심적발']
Result
# Out:
#           신고번호  우범여부  핵심적발
# 0     56458804     0     0
# 1     64425212     0     0
# 2     47734257     0     0
# 3     95067668     1     2
# 4     52721308     0     0
# ...        ...   ...   ...
# 6163  54986663     0     0
# 6164  89653615     1     1
# 6165  34737796     0     0
# 6166  29004606     0     0
# 6167  19393071     0     0
#
# [6168 rows x 3 columns]

# %%
Result.to_csv('./WeHave5min.csv', encoding='utf-8', index=None)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89619 entries, 0 to 89618
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   신고번호      89619 non-null  int64
#  1   신고일자      89619 non-null  object
#  2   통관지세관부호   89619 non-null  int64
#  3   신고인부호     89619 non-null  object
#  4   수입자부호     89619 non-null  object
#  5   해외거래처부호   62966 non-null  object
#  6   특송업체부호    29787 non-null  object
#  7   수입통관계획코드  89619 non-null  object
#  8   수입신고구분코드  89619 non-null  object
#  9   수입거래구분코드  89619 non-null  int64
#  10  수입종류코드    89619 non-null  int64
#  11  징수형태코드    89619 non-null  int64
#  12  신고중량(KG)  89619 non-null  float64
#  13  과세가격원화금액  89619 non-null  float64
#  14  운송수단유형코드  89619 non-null  int64
#  15  반입보세구역부호  89619 non-null  int64
#  16  HS10단위부호  89619 non-null  int64
#  17  적출국가코드    89619 non-null  object
#  18  원산지국가코드   89619 non-null  object
#  19  관세율구분코드   89619 non-null  object
#  20  관세율       89619 non-null  float64
#  21  우범여부      89619 non-null  int64
#  22  핵심적발      89619 non-null  int64
# dtypes: float64(3), int64(10), object(10)
# memory usage: 15.7+ MB

# %%
# 2. 안중요한 열 삭제(수입거래 구분코드, 신고중량(평균무게 기준으로 나눴을때),
# 통관지세관 부호, 운송수단 유형 코드,수입종류 코드 5개만 사용)

train_df2=train_df.drop(columns=['신고일자','신고인부호','수입자부호',
                                '해외거래처부호','특송업체부호','수입통관계획코드',
                                '수입신고구분코드','적출국가코드','원산지국가코드',
                                '관세율구분코드'])

train_df2
# Out:
#          신고번호  통관지세관부호  수입거래구분코드  수입종류코드  징수형태코드  신고중량(KG)      과세가격원화금액  \
# 0       37453       40        15      21      11    4181.6  1.207812e+04
# 1      150339       20        15      21      11    7977.0  5.938688e+05
# 2       55710       10        94      21      11     246.0  6.238490e+04
# 3      413154       20        15      21      11    4435.3  4.321373e+06
# 4      223511       40        15      21      11    4564.4  1.212105e+06
# ...       ...      ...       ...     ...     ...       ...           ...
# 89614  219831       20        11      21      14    4092.0  6.750686e+05
# 89615   53949       40        15      21      11    5098.0  7.772372e+05
# 89616  481979       20        15      21      11    4728.2  7.519390e+05
# 89617  265106       16        11      21      11    5236.2  9.952920e+03
# 89618   21960       20        15      21      11    5358.6  1.490871e+07
#
#        운송수단유형코드  반입보세구역부호    HS10단위부호   관세율  우범여부  핵심적발
# 0            40   4077180  4202999000   8.0     0     0
# 1            10   4002001  9503003919   8.0     0     0
# 2            40  15002001  8708290000   3.2     1     2
# 3            10   4002001  2933699099   0.0     0     0
# 4            10   2002079  6205200000  13.0     0     0
# ...         ...       ...         ...   ...   ...   ...
# 89614        10   2006033  3402209000   6.5     1     2
# 89615        10   2002079  8214200000   0.0     0     0
# 89616        40   4106006  3304991000   6.5     0     0
# 89617        10   4077009  3926909000   6.5     0     0
# 89618        10   4002001  6214200000   3.2     0     0
#
# [89619 rows x 13 columns]

# %%
train_df2['신고중량(KG)'].mean()
# Out:
# 5136.165625592787

# %%
is_wgt_over = train_df2['신고중량(KG)'] > train_df2['신고중량(KG)'].mean()
is_wgt_less = train_df2['신고중량(KG)'] <= train_df2['신고중량(KG)'].mean()

over_train_df2 = train_df2[is_wgt_over]
less_train_df2 = train_df2[is_wgt_less]

# %%
over_train_df2.head()
# Out:
#     통관지세관부호  수입거래구분코드  수입종류코드  징수형태코드  신고중량(KG)  운송수단유형코드  우범여부  핵심적발
# 1        20        15      21      11    7977.0        10     0     0
# 6        20        11      21      11    5968.9        10     0     0
# 11       20        15      21      11    5817.9        10     0     0
# 19       30        11      11      11    5321.7        40     0     0
# 20       13        15      21      11   13247.5        50     1     2

# %%
less_train_df2.head()
# Out:
#    통관지세관부호  수입거래구분코드  수입종류코드  징수형태코드  신고중량(KG)  운송수단유형코드  우범여부  핵심적발
# 0       40        15      21      11    4181.6        40     0     0
# 2       10        94      21      11     246.0        40     1     2
# 3       20        15      21      11    4435.3        10     0     0
# 4       40        15      21      11    4564.4        10     0     0
# 5       20        11      21      21    1963.5        10     0     0

# %%
# 중량 합친거

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np

X = train_df2.iloc[:, :-2]
y = train_df2.iloc[:, -1:]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=1)

forest = RandomForestClassifier(n_estimators=20, max_depth=10, random_state=1)
forest.fit(X_train,np.ravel(y_train))

predict = forest.predict(X_test)
print(accuracy_score(y_test,predict))
# Out:
# 0.7792010711894667

# %%
# 중량 나눈거 (over)

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np

X = over_train_df2.iloc[:, :-2]
y = over_train_df2.iloc[:, -1:]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=1)

forest = RandomForestClassifier(n_estimators=20, max_depth=10, random_state=1)
forest.fit(X_train,np.ravel(y_train))

predict = forest.predict(X_test)
print(accuracy_score(y_test,predict))
# Out:
# 0.8372177713037144

# %%
# 중량 나눈거 (less)

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np

X = less_train_df2.iloc[:, :-2]
y = less_train_df2.iloc[:, -1:]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=1)

forest = RandomForestClassifier(n_estimators=20, max_depth=10, random_state=1)
forest.fit(X_train,np.ravel(y_train))

predict = forest.predict(X_test)
print(accuracy_score(y_test,predict))
# Out:
# 0.7592526900792244

# %% [markdown]
# # 요기서부터!!

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier ## RF
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

train_df = pd.read_csv('../data/train.csv', encoding='utf-8')
test_df = pd.read_csv('../data/test.csv', encoding='utf-8')

# %%
def data_preprocessing(df):
    df['신고일자'] = list(map(lambda x : re.sub('[^0-9]+', '', x), df['신고일자']))
    labels, classes = label_encoder(df['신고인부호'])
    df['신고인부호'] = labels
    labels, classes = label_encoder(df['수입자부호'])
    df['수입자부호'] = labels
    labels, classes = label_encoder(df['해외거래처부호'])
    df['해외거래처부호'] = labels
    labels, classes = label_encoder(df['특송업체부호'])
    df['특송업체부호'] = labels
    df['수입통관계획코드'] = list(map(lambda x : ord(x), df['수입통관계획코드']))
    df['수입신고구분코드'] = list(map(lambda x : ord(x), df['수입신고구분코드']))
    labels, classes = label_encoder(df['적출국가코드'])
    df['적출국가코드'] = labels
    labels, classes = label_encoder(df['원산지국가코드'])
    df['원산지국가코드'] = labels
    labels, classes = label_encoder(df['관세율구분코드'])
    df['관세율구분코드'] = labels

# %%
train_df.describe()
# Out:
#                 신고번호       통관지세관부호      수입거래구분코드        수입종류코드        징수형태코드  \
# count   89619.000000  89619.000000  89619.000000  89619.000000  89619.000000
# mean   254785.095661     30.511231     25.615349     20.353218     13.494014
# std    141877.592785     17.369680     29.687903      2.737098      8.236691
# min     10003.000000     10.000000     11.000000     11.000000      0.000000
# 25%    131556.000000     20.000000     11.000000     21.000000     11.000000
# 50%    254746.000000     30.000000     11.000000     21.000000     11.000000
# 75%    378137.500000     40.000000     15.000000     21.000000     11.000000
# max    499996.000000    154.000000     96.000000     35.000000     43.000000
#
#             신고중량(KG)      과세가격원화금액      운송수단유형코드      반입보세구역부호      HS10단위부호  \
# count   89619.000000  8.961900e+04  89619.000000  8.961900e+04  8.961900e+04
# mean     5136.165626  1.180696e+07     25.728808  3.117949e+06  5.863890e+09
# std     11037.841957  6.508539e+08     15.442932  1.636472e+06  2.722417e+09
# min         0.900000  0.000000e+00     10.000000  1.002014e+06  1.012910e+08
# 25%      1848.750000  3.912951e+04     10.000000  2.006093e+06  3.824999e+09
# 50%      3694.700000  2.318221e+05     40.000000  3.077026e+06  6.206900e+09
# 75%      5105.150000  1.092354e+06     40.000000  4.077004e+06  8.515909e+09
# max    218140.700000  1.674020e+11     90.000000  1.550000e+07  9.706009e+09
#
#                 관세율          우범여부          핵심적발
# count  89619.000000  89619.000000  89619.000000
# mean       8.373491      0.220746      0.334829
# std       25.569044      0.414752      0.671483
# min        0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000
# 50%        6.500000      0.000000      0.000000
# 75%        8.000000      0.000000      0.000000
# max      800.300000      1.000000      2.000000

# %%
test_df.describe()
# Out:
#                 신고번호       통관지세관부호      수입거래구분코드        수입종류코드        징수형태코드  \
# count   10273.000000  10273.000000  10273.000000  10273.000000  10273.000000
# mean   754535.461014     30.585613     25.928551     20.351893     13.501022
# std    142105.800370     17.465768     29.946496      2.752811      8.167125
# min    510041.000000     10.000000     11.000000     11.000000      0.000000
# 25%    630360.000000     20.000000     11.000000     21.000000     11.000000
# 50%    752482.000000     30.000000     11.000000     21.000000     11.000000
# 75%    879861.000000     40.000000     15.000000     21.000000     11.000000
# max    999959.000000    154.000000     96.000000     35.000000     43.000000
#
#             신고중량(KG)      과세가격원화금액      운송수단유형코드      반입보세구역부호      HS10단위부호  \
# count   10273.000000  1.027300e+04  10273.000000  1.027300e+04  1.027300e+04
# mean     5191.000516  2.745955e+07     25.693566  3.095202e+06  5.828239e+09
# std     11549.745962  1.891557e+09     15.381580  1.537719e+06  2.727754e+09
# min         1.500000  0.000000e+00     10.000000  1.002014e+06  1.012910e+08
# 25%      1707.800000  3.759714e+04     10.000000  2.006099e+06  3.818001e+09
# 50%      3634.300000  2.187246e+05     40.000000  3.077024e+06  6.206900e+09
# 75%      5023.000000  1.108050e+06     40.000000  4.077004e+06  8.505200e+09
# max    197277.600000  1.893330e+11     90.000000  1.540200e+07  9.706009e+09
#
#                 관세율
# count  10273.000000
# mean       7.810649
# std       19.133155
# min        0.000000
# 25%        0.000000
# 50%        6.500000
# 75%        8.000000
# max      513.600000

# %%
data_preprocessing(train_df)
train_df.rename(columns={'신고중량(KG)':'신고중량'}, inplace=True)

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
font_path = "c:/Windows/fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family=font_name)

# 데이터 간의 상관관계를 그래프로 표현해 봅니다.
colormap = plt.cm.gist_heat   #그래프의 색상 구성을 정합니다.
plt.figure(figsize=(12,12))   #그래프의 크기를 정합니다.

# 그래프의 속성을 결정합니다. vmax의 값을 0.5로 지정해 0.5에 가까울 수록 밝은 색으로 표시되게 합니다.
sns.heatmap(train_df.corr(),linewidths=0.05,vmax=0.2, cmap=colormap, linecolor='white', annot=True)
plt.show()

# %%
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

model=ols('핵심적발~수입거래구분코드', train_df).fit()
print(anova_lm(model)) # pvalue : PR
print()

model=ols('핵심적발~징수형태코드', train_df).fit()
print(anova_lm(model)) # pvalue : PR
print()

model=ols('핵심적발~수입신고구분코드', train_df).fit()
print(anova_lm(model)) # pvalue : PR
print()

model=ols('핵심적발~수입통관계획코드', train_df).fit()
print(anova_lm(model)) # pvalue : PR
print()

model=ols('핵심적발~통관지세관부호', train_df).fit()
print(anova_lm(model)) # pvalue : PR
print()

model=ols('핵심적발~수입종류코드', train_df).fit()
print(anova_lm(model)) # pvalue : PR
print()

model=ols('핵심적발~운송수단유형코드', train_df).fit()
print(anova_lm(model)) # pvalue : PR
print()

model=ols('핵심적발~신고중량', train_df).fit()
print(anova_lm(model)) # pvalue : PR
print()

# model=ols('핵심적발~수입거래구분코드+징수형태코드+수입신고구분코드+수입통관계획코드+통관지세관부호+수입종류코드+운송수단유형코드+신고중량', train_df).fit()
# model.summary()
# Out:
#                df        sum_sq     mean_sq            F  PR(>F)
# 수입거래구분코드      1.0    931.121863  931.121863  2113.763182     0.0
# Residual  89617.0  39476.677777    0.440504          NaN     NaN
#
#                df        sum_sq     mean_sq            F         PR(>F)
# 징수형태코드        1.0    500.256034  500.256034  1123.382723  9.032615e-245
# Residual  89617.0  39907.543606    0.445312          NaN            NaN
#
#                df        sum_sq     mean_sq           F         PR(>F)
# 수입신고구분코드      1.0    379.752753  379.752753  850.211418  4.874368e-186
# Residual  89617.0  40028.046887    0.446657         NaN            NaN
#
#                df        sum_sq     mean_sq           F         PR(>F)
# 수입통관계획코드      1.0    336.722830  336.722830  753.064112  4.189972e-165
# Residual  89617.0  40071.076811    0.447137         NaN            NaN
#
#                df        sum_sq     mean_sq           F         PR(>F)
# 통관지세관부호       1.0    283.859631  283.859631  634.001759  2.063996e-139
# Residual  89617.0  40123.940010    0.447727         NaN            NaN
#
#                df        sum_sq     mean_sq           F         PR(>F)
# 수입종류코드        1.0    271.089270  271.089270  605.286454  3.290815e-133
# Residual  89617.0  40136.710371    0.447869         NaN            NaN
#
#                df        sum_sq     mean_sq           F        PR(>F)
# 운송수단유형코드      1.0    174.534686  174.534686  388.764744  2.345926e-86
# Residual  89617.0  40233.264955    0.448947         NaN           NaN
#
#                df        sum_sq    mean_sq          F        PR(>F)
# 신고중량          1.0     65.577083  65.577083  145.67421  1.624043e-33
# Residual  89617.0  40342.222558   0.450163        NaN           NaN

# %%
# li = ['수입거래구분코드','징수형태코드','수입신고구분코드','수입통관계획코드','통관지세관부호','수입종류코드','운송수단유형코드','신고중량']

# # ax = sns.scatterplot(x='징수형태코드', y='수입신고구분코드', hue='핵심적발', data=train_df)
# # ax = sns.scatterplot(x='징수형태코드', y='수입거래구분코드', hue='핵심적발', data=train_df)
# ax = sns.scatterplot(x='수입거래구분코드', y='운송수단유형코드', hue='핵심적발', data=train_df)

# %%
import re
from sklearn.preprocessing import LabelEncoder #트리관련 ML은 ㄱㅊ
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %%
def label_encoder(items):
    encoder = LabelEncoder()
    encoder.fit(items)
    labels = encoder.transform(items)
    #print('인코딩 변환값:',labels)
    classes = encoder.classes_
    #print('인코딩 클래스:',classes)
    return labels, classes

# %%
def tts(df):
    X = df.iloc[:, :-2]
    y = df.iloc[:, -1:]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=1)
    return X_train, X_test, y_train, y_test

# %%
#####학습코드

df = train_df
# df = train_df.drop(columns=['해외거래처부호','특송업체부호'])
# data_preprocessing(df)

is_wgt_over = df['신고중량(KG)'] > df['신고중량(KG)'].mean()
is_wgt_less = df['신고중량(KG)'] <= df['신고중량(KG)'].mean()
over_df = df[is_wgt_over]
less_df = df[is_wgt_less]

X_train, X_test, y_train, y_test = tts(df)
forest = RandomForestClassifier(n_estimators=20, max_depth=10, random_state=1)
forest.fit(X_train,np.ravel(y_train))
predict = forest.predict(X_test)
acc = accuracy_score(y_test,predict)

X_train, X_test, y_train, y_test = tts(over_df)
over_forest = RandomForestClassifier(n_estimators=20, max_depth=10, random_state=1)
over_forest.fit(X_train,np.ravel(y_train))
over_predict = over_forest.predict(X_test)
over_acc = accuracy_score(y_test,over_predict)

X_train, X_test, y_train, y_test = tts(less_df)
less_forest = RandomForestClassifier(n_estimators=20, max_depth=10, random_state=1)
less_forest.fit(X_train,np.ravel(y_train))
less_predict = less_forest.predict(X_test)
less_acc = accuracy_score(y_test,less_predict)

print(f'acc:{acc}, o_acc:{over_acc}, l_acc:{less_acc}')
# Out:
# acc:0.7802276277616603, o_acc:0.8383102694828842, l_acc:0.7600804067636278

# %%
##### train데이터 전체로 학습

df = train_df
# data_preprocessing(df)

is_wgt_over = df['신고중량(KG)'] > df['신고중량(KG)'].mean()
is_wgt_less = df['신고중량(KG)'] <= df['신고중량(KG)'].mean()
over_df = df[is_wgt_over]
less_df = df[is_wgt_less]

# X_train, X_test, y_train, y_test = tts(df)
X = df.iloc[:, :-2]
y = df.iloc[:, -1:]
forest = RandomForestClassifier(n_estimators=20, max_depth=10, random_state=1)
forest.fit(X,np.ravel(y))
# predict = forest.predict(X_test)
# acc = accuracy_score(y_test,predict)

# X_train, X_test, y_train, y_test = tts(over_df)
X = over_df.iloc[:, :-2]
y = over_df.iloc[:, -1:]
over_forest = RandomForestClassifier(n_estimators=20, max_depth=10, random_state=1)
over_forest.fit(X,np.ravel(y))
# over_predict = over_forest.predict(X_test)
# over_acc = accuracy_score(y_test,over_predict)

# X_train, X_test, y_train, y_test = tts(less_df)
X = less_df.iloc[:, :-2]
y = less_df.iloc[:, -1:]
less_forest = RandomForestClassifier(n_estimators=20, max_depth=10, random_state=1)
less_forest.fit(X,np.ravel(y))
# less_predict = less_forest.predict(X_test)
# less_acc = accuracy_score(y_test,less_predict)

# print(f'acc:{acc}, o_acc:{over_acc}, l_acc:{less_acc}')
# Out:
# acc:0.7876813211336755, o_acc:0.5144686907020873, l_acc:0.5144686907020873

# %%
#####테스트코드
# df=test_df.drop(columns=['신고일자','신고인부호','수입자부호',
#                         '해외거래처부호','특송업체부호','수입통관계획코드',
#                         '수입신고구분코드','적출국가코드','원산지국가코드',
#                         '관세율구분코드'])
df = test_df
data_preprocessing(df)
df.rename(columns={'신고중량(KG)':'신고중량'})

is_wgt_over = df['신고중량'] > df['신고중량'].mean()
is_wgt_less = df['신고중량'] <= df['신고중량'].mean()
over_df = df[is_wgt_over]
less_df = df[is_wgt_less]

over_predict = over_forest.predict(over_df)
# less_predict = less_forest.predict(less_df)
less_predict = forest.predict(less_df)
predict = np.concatenate((over_predict,less_predict))

predict_df = pd.DataFrame(predict)

over_신고번호 = over_df.iloc[:, 0]
less_신고번호 = less_df.iloc[:, 0]
신고번호 = pd.concat([over_신고번호, less_신고번호], axis=0)
신고번호.reset_index(drop=True, inplace=True)
신고번호 = pd.DataFrame(신고번호)

li = []
for x in predict:
    if x == 0:
        li.append(0)
    else:
        li.append(1)
우범여부 = pd.DataFrame(li)
Result = pd.concat([신고번호, 우범여부, predict_df], axis=1)
Result.columns = ['신고번호', '우범여부', '핵심적발']

Result
# Out:
#          신고번호  우범여부  핵심적발
# 0      828961     0     0
# 1      522066     0     0
# 2      624568     0     0
# 3      919935     0     0
# 4      595967     0     0
# ...       ...   ...   ...
# 10268  766961     0     0
# 10269  857321     0     0
# 10270  621501     1     2
# 10271  998367     0     0
# 10272  707900     0     0
#
# [10273 rows x 3 columns]

# %%
#예측결과
predict_df.value_counts()
# Out:
# 0    10178
# 2       63
# 1       32
# dtype: int64

# %%
#인덱스 싱크 맞추기
origin_idx = list(test_df.iloc[:, 0])
before_idx = list(Result['신고번호'])

data = {}
Result_sort = pd.DataFrame(data)

for o in origin_idx:
    for b in range(len(before_idx)):
        if before_idx[b]==o:
            Result_sort = Result_sort.append({'신고번호':Result.iloc[b][0],
                                  '우범여부':Result.iloc[b][1],
                                  '핵심적발':Result.iloc[b][2]}, ignore_index=True)
            break

Result_sort
# Out:
#            신고번호  우범여부  핵심적발
# 0      982834.0   0.0   0.0
# 1      828961.0   0.0   0.0
# 2      522066.0   0.0   0.0
# 3      999547.0   0.0   0.0
# 4      919320.0   0.0   0.0
# ...         ...   ...   ...
# 10268  857321.0   0.0   0.0
# 10269  621501.0   1.0   2.0
# 10270  998367.0   0.0   0.0
# 10271  697376.0   0.0   0.0
# 10272  707900.0   0.0   0.0
#
# [10273 rows x 3 columns]

# %%
Result_sort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10273 entries, 0 to 10272
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   신고번호    10273 non-null  float64
#  1   우범여부    10273 non-null  float64
#  2   핵심적발    10273 non-null  float64
# dtypes: float64(3)
# memory usage: 240.9 KB

# %%
Result_sort = Result_sort.astype('int')

# %%
#결과 동일한지 체크
Result_sort['핵심적발'].value_counts()
# Out:
# 0    10178
# 2       63
# 1       32
# Name: 핵심적발, dtype: int64

# %%
Result_sort.to_csv('../WeHave5min.csv', encoding='utf-8', index=None)
